-- %% [markdown]
-- # Practica 12 - Funciones esenciales en SQL

-- %% [markdown]
-- ## Parte 1. Responder utilizando el schema **base.sql**

-- %% [markdown]
-- ## Funciones String & Fecha

-- %%
USE base33;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00

-- %% [markdown]
-- **1\. ¿Cuál es el nombre y apellido más largo de nuestros vendedores?**

-- %%
SELECT MAX(Length(Apellido)),Max(Length(Nombre)),Apellido,Nombre from vendedor GROUP BY Apellido,Nombre ORDER BY MAX(Length(Apellido+Nombre));
-- Out:
-- (48 row(s) affected)
-- Total execution time: 00:00:01.005
-- <table><tr><th>MAX(Length(Apellido))</th><th>Max(Length(Nombre))</th><th>Apellido</th><th>Nombre</th></tr><tr><td>7</td><td>7</td><td>SANCHEZ</td><td>ANTONIO</td></tr><tr><td>5</td><td>6</td><td>ADELA</td><td>MANUEL</td></tr><tr><td>8</td><td>4</td><td>MARTINEZ</td><td>JOSE</td></tr><tr><td>8</td><td>9</td><td>CARRASCO</td><td>FRANCISCO</td></tr><tr><td>6</td><td>5</td><td>CUEVAS</td><td>DAVID</td></tr><tr><td>7</td><td>4</td><td>FERRERO</td><td>JUAN</td></tr><tr><td>6</td><td>12</td><td>MADERO</td><td>JOSE ANTONIO</td></tr><tr><td>4</td><td>6</td><td>LEON</td><td>JAVIER</td></tr><tr><td>9</td><td>6</td><td>HERNANDEZ</td><td>DANIEL</td></tr><tr><td>8</td><td>9</td><td>MARTINEZ</td><td>JOSE LUIS</td></tr><tr><td>6</td><td>16</td><td>GARCIA</td><td>FRANCISCO JAVIER</td></tr><tr><td>9</td><td>6</td><td>FERNANDEZ</td><td>CARLOS</td></tr><tr><td>5</td><td>5</td><td>PEREZ</td><td>JESUS</td></tr><tr><td>7</td><td>9</td><td>JIMENEZ</td><td>ALEJANDRO</td></tr><tr><td>4</td><td>6</td><td>RUIZ</td><td>MIGUEL</td></tr><tr><td>5</td><td>13</td><td>SAENZ</td><td>MARIA DOLORES</td></tr><tr><td>8</td><td>5</td><td>GONZALEZ</td><td>LAURA</td></tr><tr><td>5</td><td>12</td><td>LOPEZ</td><td>MARIA TERESA</td></tr><tr><td>5</td><td>3</td><td>GOMEZ</td><td>ANA</td></tr><tr><td>9</td><td>8</td><td>RODRIGUEZ</td><td>CRISTINA</td></tr><tr><td>6</td><td>5</td><td>MORENO</td><td>MARTA</td></tr><tr><td>6</td><td>13</td><td>ALONSO</td><td>MARIA ANGELES</td></tr><tr><td>7</td><td>9</td><td>PASCUAL</td><td>FRANCISCA</td></tr><tr><td>9</td><td>5</td><td>GUTIERREZ</td><td>LUCIA</td></tr><tr><td>3</td><td>12</td><td>GIL</td><td>MARIA ISABEL</td></tr><tr><td>4</td><td>10</td><td>DIAZ</td><td>MARIA JOSE</td></tr><tr><td>5</td><td>7</td><td>MARIN</td><td>ANTONIA</td></tr><tr><td>8</td><td>7</td><
L</td></tr><tr><td>DOLORES EZQUERRO</td></tr><tr><td>ANTONIO SANCHEZ</td></tr><tr><td>LUCIA GUTIERREZ</td></tr><tr><td>JUAN JOSE CALVO</td></tr><tr><td>MARIA JOSE DIAZ</td></tr><tr><td>ADRIAN SANCHEZ</td></tr><tr><td>LAURA GONZALEZ</td></tr><tr><td>ROBERTO MARTIN</td></tr><tr><td>ANTONIA MARIN</td></tr><tr><td>JOSE MARTINEZ</td></tr><tr><td>JOAQUIN OCHOA</td></tr><tr><td>SANTIAGO DIAZ</td></tr><tr><td>VICTOR ORTEGA</td></tr><tr><td>EDUARDO HERCE</td></tr><tr><td>JAIME GABARRI</td></tr><tr><td>MARTA MORENO</td></tr><tr><td>ALVARO RUBIO</td></tr><tr><td>INES GARRIDO</td></tr><tr><td>JUAN FERRERO</td></tr><tr><td>LORENA MUNOZ</td></tr><tr><td>DAVID CUEVAS</td></tr><tr><td>MANUEL ADELA</td></tr><tr><td>MIGUEL RUIZ</td></tr><tr><td>JESUS PEREZ</td></tr><tr><td>JAVIER LEON</td></tr><tr><td>MARIO LEON</td></tr><tr><td>ANA GOMEZ</td></tr></table>

-- %% [markdown]
-- **2\. Obtener las ventas totales para los últimos 3 años**

-- %%
Select fventa from ventas ORDER BY fventa desc limit 9;
-- Out:
-- (9 row(s) affected)
-- Total execution time: 00:00:01.013
-- <table><tr><th>fventa</th></tr><tr><td>9-Sep-18</td></tr><tr><td>9-Sep-18</td></tr><tr><td>9-Sep-17</td></tr><tr><td>9-Sep-17</td></tr><tr><td>9-Sep-17</td></tr><tr><td>9-Sep-16</td></tr><tr><td>9-Sep-16</td></tr><tr><td>9-Sep-16</td></tr><tr><td>9-Sep-16</td></tr></table>

-- %%
SELECT SUM(Venta) FROM ventas WHEN fventa BETWEEN '01-Jan-2016' AND '31-Dec-2018';
-- Out:
-- Total execution time: 00:00:00.001
-- : 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'WHEN fventa BETWEEN '01-Jan-2016' AND '31-Dec-2018'' at line 1

-- %% [markdown]
-- ## Condicional IF

-- %% [markdown]
-- **3\. Genera una lista para dar seguimiento a las ventas mayores a $ 2.9 M en 2019**

-- %%
SELECT venta,fventa,
IF (venta>2900000,"Seguimiento", "-") AS Los_mas_Top
FROM ventas
ORDER BY Los_mas_Top DESC;
-- Out:
-- (3337 row(s) affected)
-- Total execution time: 00:00:01.013
-- <table><tr><th>venta</th><th>fventa</th><th>Los_mas_Top</th></tr><tr><td>2937300</td><td>1-Jan-16</td><td>Seguimiento</td></tr><tr><td>2923155</td><td>11-Jun-16</td><td>Seguimiento</td></tr><tr><td>2909412</td><td>8-Oct-18</td><td>Seguimiento</td></tr><tr><td>2977318</td><td>28-Aug-18</td><td>Seguimiento</td></tr><tr><td>2902284</td><td>2-Jul-19</td><td>Seguimiento</td></tr><tr><td>2908500</td><td>29-Mar-19</td><td>Seguimiento</td></tr><tr><td>2914416</td><td>4-
-- %% [markdown]
-- ## El primero no consigo meter la fecha.
--
-- ![](data:image/png;base64,...)
--
-- ## De la segunda forma sí puedo, porque digo RIGHT (fventa,2) ='19' significa que seleccione, empezando por la derecha **RIGHT** en todas las celdas de la columna "**fventa**(fecha venta)", los últimos **2** dos digitos, que acaben en **19** (2019)".
--
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ## Parte 2. Uso de IF y CASE. Responder usando otra base de datos que se creará a continuación:

-- %% [markdown]
-- -  <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); font-weight: var(--cib-type-body1-font-weight); white-space-collapse: preserve;">Crear la base de datos 'market' si no existe:</span>

-- %%
CREATE DATABASE IF NOT EXISTS market;
USE market;
-- Out:
-- Commands completed successfully
-- Commands completed successfully
-- Total execution time: 00:00:00.017

-- %% [markdown]
-- - Crear la tabla 'Ventas'

-- %%
CREATE TABLE Ventas (
    ID INT AUTO_INCREMENT PRIMARY KEY,
    Producto VARCHAR(100),
    Cantidad INT,
    Precio DECIMAL(10,2),
    Descuento DECIMAL(5,2)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.046

-- %% [markdown]
-- - Insertar 10 registros en 'Ventas'

-- %%
INSERT INTO Ventas (Producto, Cantidad, Precio, Descuento) VALUES
('Laptop', 1, 1200.00, 0),
('Smartphone', 2, 300.00, 15.00),
('Teclado', 5, 50.00, 5.00),
('Monitor', 2, 200.00, 10.00),
('Mouse', 10, 20.00, 2.00),
('Cámara Web', 3, 70.00, 5.00),
('Altavoces', 4, 35.00, 3.50),
('Impresora', 1, 85.00, 0),
('Router', 2, 60.00, 0),
('Tablet', 5, 250.00, 12.50);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.009

-- %% [markdown]
-- ### _Una vez creada la base de datos y la tabla responder las siguientes preguntas usando IF y/o CASE_

-- %% [markdown]
-- **4.**  <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Aplicar descuento si la cantidad es mayor a 3</b></span>

-- %%
SELECT *,
CASE
    WHEN cantidad > 3 THEN "Aplicar"
    ELSE "-"
END AS Descuento
FROM ventas;
-- Out:
-- Total execution time: 00:00:00

-- %% [markdown]
-- **5.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Clasificar productos como 'Caro' o 'Barato' basado en el precio. Establezca usted mismo el criterio de 'Caro' y 'Barato'</b></span>

-- %%
SELECT *,
    CASE 
    WHEN Precio > 249.00 THEN 'Caro'
    WHEN Precio < 249.00 OR Precio = 249.00 THEN 'Barato'
    END AS Clasificacion
FROM ventas;
-- Out:
-- (10 row(s) affected)
-- Total execution time: 00:00:01.004
-- <table><tr><th>ID</th><th>Producto</th><th>Cantidad</th><th>Precio</th><th>Descuento</th><th>Clasificacion</th></tr><tr><td>1</td><td>Laptop</td><td>1</td><td>1200.00</td><td>0.00</td><td>Caro</td></tr><tr><td>2</td><td>Smartphone</td><td>2</td><td>300.00</td><td>15.00</td><td>Caro</td></tr><tr><td>3</td><td>Teclado</td><td>5</td><td>50.00</td><td>5.00</td><td>Barato</td></tr><tr><td>4</td><td>Monitor</td><td>2</td><td>200.00</td><td>10.00</td><td>Barato</td></tr><tr><td>5</td><td>Mouse</td><td>10</td><td>20.00</td><td>2.00</td><td>Barato</td></tr><tr><td>6</td><td>Cámara Web</td><td>3</td><td>70.00</td><td>5.00</td><td>Barato</td></tr><tr><td>7</td><td>Altavoces</td><td>4</td><td>35.00</td><td>3.50</td><td>Barato</td></tr><tr><td>8</td><td>Impresora</td><td>1</td><td>85.00</td><td>0.00</td><td>Barato</td></tr><tr><td>9</td><td>Router</td><td>2</td><td>60.00</td><td>0.00</td><td>Barato</td></tr><tr><td>10</td><td>Tablet</td><td>5</td><td>250.00</td><td>12.50</td><td>Caro</td></tr></table>

-- %% [markdown]
-- **6.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Calcular el total de ventas con y sin descuento</b></span>

-- %%
SELECT SUM(Precio) as Total_sin_descuento,SUM(Precio-Descuento) as Total_con_descuento
FROM ventas
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.004
-- <table><tr><th>Total_sin_descuento</th><th>Total_con_descuento</th></tr><tr><td>2270.00</td><td>2217.00</td></tr></table>

-- %% [markdown]
-- **7.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Aplicar un descuento adicional del 10% a los productos que ya tienen descuento</b></span>

-- %%
USE market;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00

-- %%
SELECT Producto,SUM(Precio+(Precio*0.1)) as Descuento_final
From ventas
WHERE Descuento > 0
GROUP BY Producto;
-- Out:
-- (7 row(s) affected)
-- Total execution time: 00:00:01.352
-- <table><tr><th>Producto</th><th>Descuento_final</th></tr><tr><td>Smartphone</td><td>330.000</td></tr><tr><td>Teclado</td><td>55.000</td></tr><tr><td>Monitor</td><td>220.000</td></tr><tr><td>Mouse</td><td>22.000</td></tr><tr><td>Cámara Web</td><td>77.000</td></tr><tr><td>Altavoces</td><td>38.500</td></tr><tr><td>Tablet</td><td>275.000</td></tr></table>

-- %% [markdown]
-- **8.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Aumentar el precio de los productos en un 20% si se venden menos de 3 unidades</b></span>

-- %%
SELECT Producto,SUM(Precio+(Precio*0.2)) as Aumento
FROM ventas
WHERE Cantidad < 3
GROUP BY Producto;
-- Out:
-- (5 row(s) affected)
-- Total execution time: 00:00:01.008
-- <table><tr><th>Producto</th><th>Aumento</th></tr><tr><td>Laptop</td><td>1440.000</td></tr><tr><td>Smartphone</td><td>360.000</td></tr><tr><td>Monitor</td><td>240.000</td></tr><tr><td>Impresora</td><td>102.000</td></tr><tr><td>Router</td><td>72.000</td></tr></table>

-- %% [markdown]
-- **9. <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;">Asignar un rango de ventas basado en la cantidad vendida. Establezca usted mismo los criterios, por ejemplo: ALTO, MEDIO o BAJO según en valor que consideres.</span>**

-- %%
SELECT *,
    CASE 
    WHEN Cantidad > 10 THEN 'Exito de ventas'
    WHEN Cantidad BETWEEN 5 AND 10 OR Cantidad =10 THEN 'Mantenemos igual'
    WHEN Cantidad < 5 THEN 'Trabajar en marketing'
    END AS Clasificacion
FROM ventas;
-- Out:
-- (10 row(s) affected)
-- Total execution time: 00:00:01.003
-- <table><tr><th>ID</th><th>Producto</th><th>Cantidad</th><th>Precio</th><th>Descuento</th><th>Clasificacion</th></tr><tr><td>1</td><td>Laptop</td><td>1</td><td>1200.00</td><td>0.00</td><td>Trabajar en marketing</td></tr><tr><td>2</td><td>Smartphone</td><td>2</td><td>300.00</td><td>15.00</td><td>Trabajar en marketing</td></tr><tr><td>3</td><td>Teclado</td><td>5</td><td>50.00</td><td>5.00</td><td>Mantenemos igual</td></tr><tr><td>4</td><td>Monitor</td><td>2</td><td>200.00</td><td>10.00</td><td>Trabajar en marketing</td></tr><tr><td>5</td><td>Mouse</td><td>10</td><td>20.00</td><td>2.00</td><td>Mantenemos igual</td></tr><tr><td>6</td><td>Cámara Web</td><td>3</td><td>70.00</td><td>5.00</td><td>Trabajar en marketing</td></tr><tr><td>7</td><td>Altavoces</td><td>4</td><td>35.00</td><td>3.50</td><td>Trabajar en marketing</td></tr><tr><td>8</td><td>Impresora</td><td>1</td><td>85.00</td><td>0.00</td><td>Trabajar en marketing</td></tr><tr><td>9</td><td>Router</td><td>2</td><td>60.00</td><td>0.00</td><td>Trabajar en marketing</td></tr><tr><td>10</td><td>Tablet</td><td>5</td><td>250.00</td><td>12.50</td><td>Mantenemos igual</td></tr></table>

-- %% [markdown]
-- **10.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Determinar la categoría del producto basado en el precio</b></span>

-- %%
SELECT *,
    CASE 
    WHEN Precio > 249 THEN 'A'
    WHEN Precio BETWEEN 100 AND 249 THEN 'B'
    WHEN Precio BETWEEN 50 AND 99 OR Precio=50 THEN 'C'
    WHEN Precio < 50 THEN 'D'
    END AS Categoria
FROM ventas;
-- Out:
-- (10 row(s) affected)
-- Total execution time: 00:00:01.018
-- <table><tr><th>ID</th><th>Producto</th><th>Cantidad</th><th>Precio</th><th>Descuento</th><th>Categoria</th></tr><tr><td>1</td><td>Laptop</td><td>1</td><td>1200.00</td><td>0.00</td><td>A</td></tr><tr><td>2</td><td>Smartphone</td><td>2</td><td>300.00</td><td>15.00</td><td>A</td></tr><tr><td>3</td><td>Teclado</td><td>5</td><td>50.00</td><td>5.00</td><td>C</td></tr><tr><td>4</td><td>Monitor</td><td>2</td><td>200.00</td><td>10.00</td><td>B</td></tr><tr><td>5</td><td>Mouse</td><td>10</td><td>20.00</td><td>2.00</td><td>D</td></tr><tr><td>6</td><td>Cámara Web</td><td>3</td><td>70.00</td><td>5.00</td><td>C</td></tr><tr><td>7</td><td>Altavoces</td><td>4</td><td>35.00</td><td>3.50</td><td>D</td></tr><tr><td>8</td><td>Impresora</td><td>1</td><td>85.00</td><td>0.00</td><td>C</td></tr><tr><td>9</td><td>Router</td><td>2</td><td>60.00</td><td>0.00</td><td>C</td></tr><tr><td>10</td><td>Tablet</td><td>5</td><td>250.00</td><td>12.50</td><td>A</td></tr></table>

-- %% [markdown]
-- ## Para que me funcionara bien tenia que poner el numero más bajo primero en cada sección

-- %% [markdown]
-- **11.**  <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Aplicar un impuesto adicional para productos caros</b></span>

-- %%
SELECT Precio,Producto,SUM(Precio+Precio*0.3) as 'Impuesto Adicional'
FROM ventas
WHERE Precio > 1000
GROUP BY Producto,Precio;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.015
-- <table><tr><th>Precio</th><th>Producto</th><th>Impuesto Adicional</th></tr><tr><td>1200.00</td><td>Laptop</td><td>1560.000</td></tr></table>

-- %% [markdown]
-- **12.** <span style="color: var(--cib-color-syntax-gray); font-family: Menlo, Monaco, Consolas, &quot;Droid Sans Mono&quot;, &quot;Courier New&quot;, monospace, &quot;Droid Sans Fallback&quot;; font-size: var(--cib-type-body1-font-size); white-space-collapse: preserve;"><b>Asignar un nivel de stock basado en la cantidad. Establece tu mismo los criterios, por ejemplo: Sobrestock, stock adecuado, bajo stock.</b></span>

-- %%
SELECT *,
    CASE 
    WHEN Cantidad > 10 OR Cantidad = 10 THEN 'Bajo Stock'
    WHEN Cantidad BETWEEN 5 AND 10 THEN 'Stock adecuando'
    WHEN Cantidad < 5 THEN 'Sobrestock'
    END AS Stock
FROM ventas;
-- Out:
-- (10 row(s) affected)
-- Total execution time: 00:00:01.012
-- <table><tr><th>ID</th><th>Producto</th><th>Cantidad</th><th>Precio</th><th>Descuento</th><th>Stock</th></tr><tr><td>1</td><td>Laptop</td><td>1</td><td>1200.00</td><td>0.00</td><td>Sobrestock</td></tr><tr><td>2</td><td>Smartphone</td><td>2</td><td>300.00</td><td>15.00</td><td>Sobrestock</td></tr><tr><td>3</td><td>Teclado</td><td>5</td><td>50.00</td><td>5.00</td><td>Stock adecuando</td></tr><tr><td>4</td><td>Monitor</td><td>2</td><td>200.00</td><td>10.00</td><td>Sobrestock</td></tr><tr><td>5</td><td>Mouse</td><td>10</td><td>20.00</td><td>2.00</td><td>Bajo Stock</td></tr><tr><td>6</td><td>Cámara Web</td><td>3</td><td>70.00</td><td>5.00</td><td>Sobrestock</td></tr><tr><td>7</td><td>Altavoces</td><td>4</td><td>35.00</td><td>3.50</td><td>Sobrestock</td></tr><tr><td>8</td><td>Impresora</td><td>1</td><td>85.00</td><td>0.00</td><td>Sobrestock</td></tr><tr><td>9</td><td>Router</td><td>2</td><td>60.00</td><td>0.00</td><td>Sobrestock</td></tr><tr><td>10</td><td>Tablet</td><td>5</td><td>250.00</td><td>12.50</td><td>Stock adecuando</td></tr></table>
